# %%
from IPython.display import display

import pandas as pd
import numpy as np

from utils import load_dataset, clean_dataset
from bias_utils import aequitas_preprocessing, df_to_aequitas, fairness_report


from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness

# %%
df = load_dataset()
df = clean_dataset(df) # select only searched entries, location preprocessed

# %%
display(df.head(2))
display(df.shape)
# Out:
#      VehicleSearchedIndicator  ContrabandIndicator Department Name  \
# 71                       True                False      Bridgeport
# 143                      True                 True         Milford
#
#     InterventionDateTime InterventionLocationName InterventionReasonCode  \
# 71   2013-10-01 00:46:00               bridgeport                      V
# 143  2013-10-01 01:50:00                  milford                      E
#
#     ReportingOfficerIdentificationID  ResidentIndicator  \
# 71                              1207               True
# 143                             2325               True
#
#     SearchAuthorizationCode     StatuteReason  SubjectAge  \
# 71                        I     Speed Related        37.0
# 143                       I  Defective Lights        30.0
#
#     SubjectEthnicityCode SubjectRaceCode SubjectSexCode  TownResidentIndicator
# 71                     H               W              M                   True
# 143                    N               W              M                   True
# (76743, 15)

# %%
def departments_fairness_report(df: pd.DataFrame, size_threshold = 100) -> list:
    """
    Evaluate fairness for all departments.
    Only account for those who have at least <size_threshold>
    instances of searched vehicles.
    """
    _df = df.copy()
    departments_clean_fairness = []
    departments_ignored_size = []
    failed_fairness_departments = {}
    report = {}
    
    protected_classes = ['SubjectAge','SubjectRaceCode','SubjectSexCode','Is State Resident?', 'Is Town Resident?']
    for department in _df['Department Name'].unique():
        print(department)
        department_df = _df[_df['Department Name'] == department].copy()
        if department_df.shape[0] < size_threshold:
            departments_ignored_size.append(department)
            continue
            
        department_df = aequitas_preprocessing(department_df)
        aequitas_df = df_to_aequitas(department_df,'VehicleSearchedIndicator', protected_classes)
        try:
            fairness_df,fairness_text_report = fairness_report(aequitas_df,text_report=True)
        except Exception as e:
            print(e)
            return aequitas_df
        
        if fairness_df.shape[0] == 0:
            departments_clean_fairness.append(department)
        else:
            failed_fairness_departments[department] = {'text_report':fairness_text_report, 'df': fairness_df}
    
    report = {'departments_clean_fairness':departments_clean_fairness,
             'departments_ignored_size':departments_ignored_size,
             'failed_fairness_departments':failed_fairness_departments}
    return report

# %%
result = departments_fairness_report(df)
# Out:
# Bridgeport
# model_id, score_thresholds 1 {'rank_abs': [1562]}
# get_disparity_predefined_group()
# Milford
# model_id, score_thresholds 1 {'rank_abs': [1224]}
# get_disparity_predefined_group()
# Torrington
# model_id, score_thresholds 1 {'rank_abs': [663]}
# get_disparity_predefined_group()
# State Police
# model_id, score_thresholds 1 {'rank_abs': [5449]}
# get_disparity_predefined_group()
# Greenwich
# model_id, score_thresholds 1 {'rank_abs': [601]}
# get_disparity_predefined_group()
# Westport
# model_id, score_thresholds 1 {'rank_abs': [837]}
# get_disparity_predefined_group()
# Middletown
# model_id, score_thresholds 1 {'rank_abs': [1178]}
# get_disparity_predefined_group()
# Naugatuck
# model_id, score_thresholds 1 {'rank_abs': [921]}
# get_disparity_predefined_group()
# West Hartford
# model_id, score_thresholds 1 {'rank_abs': [2214]}
# get_disparity_predefined_group()
# Norwalk
# model_id, score_thresholds 1 {'rank_abs': [1762]}
# get_disparity_predefined_group()
# Danbury
# model_id, score_thresholds 1 {'rank_abs': [1588]}
# get_disparity_predefined_group()
# Plainville
# model_id, score_thresholds 1 {'rank_abs': [855]}
# get_disparity_predefined_group()
# Glastonbury
# model_id, score_thresholds 1 {'rank_abs': [1213]}
# get_disparity_predefined_group()
# Newington
# model_id, score_thresholds 1 {'rank_abs': [1007]}
# get_disparity_predefined_group()
# Waterbury
# model_id, score_thresholds 1 {'rank_abs': [2506]}
# get_disparity_predefined_group()
# Groton City
# model_id, score_thresholds 1 {'rank_abs': [216]}
# get_disparity_predefined_group()
# Manchester
# model_id, score_thresholds 1 {'rank_abs': [1057]}
# get_disparity_predefined_group()
# New Milford
# model_id, score_thresholds 1 {'rank_abs': [254]}
# get_disparity_predefined_group()
# Branford
# model_id, score_thresholds 1 {'rank_abs': [488]}
# get_disparity_predefined_group()
# Ridgefield
# model_id, score_thresholds 1 {'rank_abs': [246]}
# get_disparity_predefined_group()
# Groton Town
# model_id, score_thresholds 1 {'rank_abs': [496]}
# get_disparity_predefined_group()
# Norwich
# model_id, score_thresholds 1 {'rank_abs': [2116]}
# get_disparity_predefined_group()
# Clinton
# model_id, score_thresholds 1 {'rank_abs': [530]}
# get_disparity_predefined_group()
# Meriden
# model_id, score_thresholds 1 {'rank_abs': [509]}
# get_disparity_predefined_group()
# Wilton
# model_id, score_thresholds 1 {'rank_abs': [986]}
# get_disparity_predefined_group()
# North Haven
# model_id, score_thresholds 1 {'rank_abs': [594]}
# get_disparity_predefined_group()
# Derby
# model_id, score_thresholds 1 {'rank_abs': [1098]}
# get_disparity_predefined_group()
# New Britain
# model_id, score_thresholds 1 {'rank_abs': [1587]}
# get_disparity_predefined_group()
# Newtown
# model_id, score_thresholds 1 {'rank_abs': [407]}
# get_disparity_predefined_group()
# Windsor
# model_id, score_thresholds 1 {'rank_abs': [542]}
# get_disparity_predefined_group()
# Orange
# model_id, score_thresholds 1 {'rank_abs': [175]}
# get_disparity_predefined_group()
# Darien
# model_id, score_thresholds 1 {'rank_abs': [481]}
# get_disparity_predefined_group()
# Enfield
# model_id, score_thresholds 1 {'rank_abs': [1310]}
# get_disparity_predefined_group()
# Wallingford
# model_id, score_thresholds 1 {'rank_abs': [2717]}
# get_disparity_predefined_group()
# Rocky Hill
# model_id, score_thresholds 1 {'rank_abs': [427]}
# get_disparity_predefined_group()
# Seymour
# model_id, score_thresholds 1 {'rank_abs': [353]}
# get_disparity_predefined_group()
# East Hartford
# model_id, score_thresholds 1 {'rank_abs': [1669]}
# get_disparity_predefined_group()
# Simsbury
# model_id, score_thresholds 1 {'rank_abs': [128]}
# get_disparity_predefined_group()
# New Haven
# model_id, score_thresholds 1 {'rank_abs': [5006]}
# get_disparity_predefined_group()
# DMV
# New Canaan
# model_id, score_thresholds 1 {'rank_abs': [272]}
# get_disparity_predefined_group()
# Hamden
# model_id, score_thresholds 1 {'rank_abs': [261]}
# get_disparity_predefined_group()
# Windsor Locks
# model_id, score_thresholds 1 {'rank_abs': [233]}
# get_disparity_predefined_group()
# Fairfield
# model_id, score_thresholds 1 {'rank_abs': [805]}
# get_disparity_predefined_group()
# Willimantic
# model_id, score_thresholds 1 {'rank_abs': [774]}
# get_disparity_predefined_group()
# Granby
# Plainfield
# model_id, score_thresholds 1 {'rank_abs': [261]}
# get_disparity_predefined_group()
# Old Saybrook
# model_id, score_thresholds 1 {'rank_abs': [441]}
# get_disparity_predefined_group()
# Plymouth
# model_id, score_thresholds 1 {'rank_abs': [317]}
# get_disparity_predefined_group()
# Wethersfield
# model_id, score_thresholds 1 {'rank_abs': [963]}
# get_disparity_predefined_group()
# East Hampton
# Ansonia
# model_id, score_thresholds 1 {'rank_abs': [484]}
# get_disparity_predefined_group()
# Stratford
# model_id, score_thresholds 1 {'rank_abs': [1760]}
# get_disparity_predefined_group()
# Berlin
# model_id, score_thresholds 1 {'rank_abs': [806]}
# get_disparity_predefined_group()
# Avon
# Woodbridge
# model_id, score_thresholds 1 {'rank_abs': [127]}
# get_disparity_predefined_group()
# get_disparity_predefined_groups(): reference groups and values provided do not exist as columns/values in the input dataframe.(Note: check for syntax errors)

# %%
g = Group();
xtab, _ = g.get_crosstabs(result);

size_threshold = 20
filtered_xtab = xtab[xtab.group_size > size_threshold]

# Bias through disparity scores
b = Bias();

bdf = b.get_disparity_major_group(filtered_xtab,
                                original_df = result,
                                label_score_ref='fdr')

# Fairness through 0.8 threshold on disparity
f = Fairness(tau=0.8);
fdf = f.get_group_value_fairness(bdf);

failed_fairness = fdf[fdf['FDR Parity'] == False]

important_columns = ['attribute_name', 'attribute_value','fdr_disparity','fdr_ref_group_value','FDR Parity']

# return text report of failed fairness
text_report = True
if text_report:
    report = "\nFairness Report\n----------\n"
    for idx,row in failed_fairness.iterrows():
        text = f'{row.attribute_name} : {row.attribute_value}\n'
        text += f'It is {round(row.fdr_disparity,2)} times more likely to fail in people who are {row.attribute_value} than people who are {row.fdr_ref_group_value}.\n\n'
        report += text
# Out:
# model_id, score_thresholds 1 {'rank_abs': [127]}
# get_disparity_major_group()

# %%
fdf[['attribute_name', 'attribute_value','fdr_disparity','fdr_ref_group_value','FDR Parity']]
# Out:
#        attribute_name attribute_value  fdr_disparity fdr_ref_group_value  \
# 0          SubjectAge           21-45       1.000000               21-45
# 1     SubjectRaceCode           Black       1.183575               White
# 2     SubjectRaceCode           White       1.000000               White
# 3      SubjectSexCode          Female       1.066406                Male
# 4      SubjectSexCode            Male       1.000000                Male
# 5  Is State Resident?             Yes       1.000000                 Yes
# 6   Is Town Resident?              No       1.000000                  No
#
#    FDR Parity
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True

# %%
filtered_xtab[['attribute_name','attribute_value','fdr','group_size']]
# Out:
#         attribute_name attribute_value       fdr  group_size
# 0           SubjectAge           21-45  0.723404          94
# 4      SubjectRaceCode           Black  0.777778          54
# 6      SubjectRaceCode           White  0.657143          70
# 7       SubjectSexCode          Female  0.750000          36
# 8       SubjectSexCode            Male  0.703297          91
# 9   Is State Resident?             Yes  0.716535         127
# 10   Is Town Resident?              No  0.724138         116

# %%
size_threshold = 20
filtered_xtab = xtab[xtab.group_size > size_threshold]
# Out:
# Index(['model_id', 'score_threshold', 'k', 'attribute_name', 'attribute_value',
#        'tpr', 'tnr', 'for', 'fdr', 'fpr', 'fnr', 'npv', 'precision', 'pp',
#        'pn', 'ppr', 'pprev', 'fp', 'fn', 'tn', 'tp', 'group_label_pos',
#        'group_label_neg', 'group_size', 'total_entities', 'prev'],
#       dtype='object')

# %%
xtab[['attribute_name','attribute_value','fdr','group_size']]
# Out:
#         attribute_name attribute_value       fdr  group_size
# 0           SubjectAge           21-45  0.723404          94
# 1           SubjectAge             <21  0.600000          15
# 2           SubjectAge             >45  0.777778          18
# 3      SubjectRaceCode           Asian  1.000000           2
# 4      SubjectRaceCode           Black  0.777778          54
# 5      SubjectRaceCode          Native  1.000000           1
# 6      SubjectRaceCode           White  0.657143          70
# 7       SubjectSexCode          Female  0.750000          36
# 8       SubjectSexCode            Male  0.703297          91
# 9   Is State Resident?             Yes  0.716535         127
# 10   Is Town Resident?              No  0.724138         116
# 11   Is Town Resident?             Yes  0.636364          11

# %%
failed_fairness
# Out:
#     model_id score_threshold    k attribute_name attribute_value  tpr  tnr  \
# 10         1      binary 0/1  127     SubjectAge             >45  1.0  0.0
# 11         1      binary 0/1  127     SubjectAge             >45  1.0  0.0
# 12         1      binary 0/1  127     SubjectAge             >45  1.0  0.0
# 13         1      binary 0/1  127     SubjectAge             >45  1.0  0.0
# 14         1      binary 0/1  127     SubjectAge             >45  1.0  0.0
#
#     for       fdr  fpr  ...  FNR Parity  TPR Parity  TNR Parity  NPV Parity  \
# 10  NaN  0.777778  1.0  ...         NaN        True         NaN         NaN
# 11  NaN  0.777778  1.0  ...         NaN        True         NaN         NaN
# 12  NaN  0.777778  1.0  ...         NaN        True         NaN         NaN
# 13  NaN  0.777778  1.0  ...         NaN        True         NaN         NaN
# 14  NaN  0.777778  1.0  ...         NaN        True         NaN         NaN
#
#     Precision Parity  TypeI Parity  TypeII Parity  Equalized Odds  \
# 10              True         False            NaN            True
# 11              True         False            NaN            True
# 12              True         False            NaN            True
# 13              True         False            NaN            True
# 14              True         False            NaN            True
#
#     Unsupervised Fairness  Supervised Fairness
# 10                   True                False
# 11                   True                False
# 12                   True                False
# 13                   True                False
# 14                   True                False
#
# [5 rows x 61 columns]

# %%
print(report)
# Out:
# Fairness Report
# ----------
# SubjectAge : >45
# It is 1.3 times more likely to fail in people who are >45 than people who are <21.
#
# SubjectAge : >45
# It is 1.3 times more likely to fail in people who are >45 than people who are <21.
#
# SubjectAge : >45
# It is 1.3 times more likely to fail in people who are >45 than people who are <21.
#
# SubjectAge : >45
# It is 1.3 times more likely to fail in people who are >45 than people who are <21.
#
# SubjectAge : >45
# It is 1.3 times more likely to fail in people who are >45 than people who are <21.

# %%
milford['departments_clean_fairness']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b863f4543191> in <module>
# ----> 1 milford['departments_clean_fairness']
#
# NameError: name 'milford' is not defined

# %%
milford.columns
# Out:
# Index(['SubjectAge', 'SubjectRaceCode', 'SubjectSexCode', 'Is State Resident?',
#        'Is Town Resident?', 'label_value', 'score', 'label_value', 'score'],
#       dtype='object')
